# %%
import gradio as gr
import json
import ast
import os
from video_utils import get_transcript, stitch_video_segments, describe_video, download_youtube_video
from ai_utils import model, user_input
from config import GEMINI_API_KEY, ELEVEN_LABS_API_KEY, OPENAI_API_KEY, GROQ_API_KEY
from translation_utils import dub_video_translate, get_video, get_video2

def process_video(video_path, prompt, language, is_new=False):
    video_name = os.path.basename(video_path)
    output_transcript = get_transcript(video_path, language=language)

    print("Output transcript of video: ", output_transcript)

    chat = model.start_chat() if is_new else None
    
    transcript_combined = user_input(chat, output_transcript, prompt, video_name, is_new)
    transcript_combined = ast.literal_eval(transcript_combined)
    
    try:
        transcript_combined2 = json.dumps(transcript_combined, indent=4)
    except:
        transcript_combined2 = str(transcript_combined)
        print("Pretty print failed")
    
    processed_video = stitch_video_segments(video_path, transcript_combined, 'stitched_vid.mp4')  
    
    return processed_video, video_name, transcript_combined2

def process_youtube_video(youtube_url, prompt, language, is_new=False):
    video_path = download_youtube_video(youtube_url)
    if video_path is None:
        return None, "Download failed", "Failed to download YouTube video"
    
    return process_video(video_path, prompt, language, is_new)

with gr.Blocks() as demo:
    gr.Markdown("# ThirteenLabs Smart AI Editor")
    
    with gr.Row():
        with gr.Column():
            video_input = gr.Video(label="Upload Video")
            youtube_url = gr.Textbox(label="YouTube URL")
            download_youtube_button = gr.Button("Download YouTube Video")
            prompt_input = gr.Textbox(label="Prompt-to-edit")
            language_input = gr.Dropdown(choices=["en", "es", "fr", "de", "it", "ja", "ko", "zh"], label="Language", value="en")
            describe_video_button = gr.Button("Describe Video")
            get_transcript_button = gr.Button("Get Transcript")
            process_button = gr.Button("Process Video")
            process_button2 = gr.Button("Process New Video")
            process_youtube_button = gr.Button("Process YouTube Video")
        
        with gr.Column():
            video_output = gr.Video(label="Processed Video")
            video_name_output = gr.Textbox(label="Video Name")
            transcript_output = gr.Textbox(label="Processed Transcript")
            video_description_output = gr.Textbox(label="Video Description")
    
    with gr.Row():
        dub_video_btn = gr.Button("Dub video")
        dub_video_btn2 = gr.Button("Dub video with lip sync")
        target_language = gr.Textbox(label="Target Language")
        response_out = gr.Textbox(label="Translate Status")
    
    with gr.Row():
        translated_video_out = gr.Video(label="Translated Video")
    
    with gr.Row():
        translated_video_out2 = gr.Video(label="Translated Video2")

    dub_video_btn.click(fn=get_video, inputs=[], outputs=[translated_video_out])
    dub_video_btn2.click(fn=get_video2, inputs=[], outputs=[translated_video_out2])
    describe_video_button.click(fn=describe_video, inputs=[video_input], outputs=[video_description_output])
    get_transcript_button.click(fn=get_transcript, inputs=[video_input, language_input], outputs=[transcript_output])
    process_button.click(fn=process_video, inputs=[video_input, prompt_input, language_input], outputs=[video_output, video_name_output, transcript_output])
    process_button2.click(fn=lambda *args: process_video(*args, is_new=True), inputs=[video_input, prompt_input, language_input], outputs=[video_output, video_name_output, transcript_output])
    process_youtube_button.click(fn=process_youtube_video, inputs=[youtube_url, prompt_input, language_input], outputs=[video_output, video_name_output, transcript_output])

# %%
from vertexai.generative_models import GenerativeModel, Part

# %%
def describe_video(video_path):
    try:

        # genai.configure(api_key=GEMINI_API_KEY)

        # generation_config = {
        #     "temperature": 1,
        #     "top_p": 0,
        #     "top_k": 64,
        #     "max_output_tokens": 8192,
        #     "response_mime_type": "application/json",
        # }

        # safety_settings = [
        #     {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"},
        #     {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
        #     {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
        #     {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
        # ]

        # model = genai.GenerativeModel(
        #     model_name="gemini-1.5-flash",
        #     safety_settings=safety_settings,
        #     generation_config=generation_config,
        # )

        vertexai.init(project='gen-lang-client-0004068608', location="us-west1")

        model = GenerativeModel(model_name="gemini-1.5-flash")

        # Prepare the prompt
        prompt = """
        Provide a description of the video.
        The description should also contain anything important which people say in the video.
        Include key elements such as:
        
        Main subject or focus
        Setting or environment
        Actions or events occurring
        Notable visual elements or patterns
        Any text or recognizable logos
        Important dialogues or spoken content
        Summarize your observations in 3-4 sentences.
        Provide in JSON format with keys time_start, time_end, description, objects_in_scene, dialog, characters_in_scene
        
        Example JSON format:
        jsonCopy{
          "time_start": "00:00",
          "time_end": "01:30",
          "description": "video_description",
          "objects_in_scene": ["object1", "object2", "object3", ...],
          "dialog": "transcript_of_dialog",
          "characters_in_scene": ["character1", "character2", ...]
        }
        Please provide your video description using this JSON format.
        mime_type=application/json
        Do not provide any explanation.
        Only output list of JSON
        """

        # Read the video file
        with open(video_path, "rb") as file:
            video_content = file.read()

        # Create video part
        video_file = Part.from_data(data=video_content, mime_type="video/mp4")

        # video_file_uri = video_path
        # video_file = Part.from_uri(video_file_uri, mime_type="video/mp4")
        
        # Generate content using Gemini
        contents = [video_file, prompt]
        response = model.generate_content(contents)

        return response.text

    except Exception as e:
        print(f"Error describing video: {e}")
        return "Unable to generate video description."

# %%
video_output = describe_video("/Users/dylan/jupyter/side-projects/folder-dl88/trailer-videos/Borderlands (2024) Official Trailer - Cate Blanchett Kevin Hart Jack Black.mp4")

# %%
print(video_output)
# Out:
# ```json
# [
#   {
#     "time_start": "00:00",
#     "time_end": "00:01",
#     "description": "A woman with red hair lies on a wooden platform, aiming a gun towards the screen.",
#     "objects_in_scene": ["woman", "gun", "wooden platform"],
#     "dialog": null,
#     "characters_in_scene": ["woman"]
#   },
#   {
#     "time_start": "00:01",
#     "time_end": "00:02",
#     "description": "A large, dark creature with tentacles stands in the middle of a desert landscape. It is obscured by dust and debris. The word 'TRAILER' appears in gold letters, superimposed on a background of green and blue. ",
#     "objects_in_scene": ["creature", "desert landscape", "tentacles", "dust"],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:02",
#     "time_end": "00:03",
#     "description": "A woman leaps over a table with several doll-like figures sitting on it. The setting appears to be a desert wasteland with a large, rusty metal structure in the background.",
#     "objects_in_scene": ["woman", "table", "dolls", "desert wasteland", "rusty structure"],
#     "dialog": null,
#     "characters_in_scene": ["woman"]
#   },
#   {
#     "time_start": "00:03",
#     "time_end": "00:04",
#     "description": "The word 'STARTS' appears in gold letters, superimposed on a background of purple and pink. ",
#     "objects_in_scene": [],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:04",
#     "time_end": "00:06",
#     "description": "A small robot with a yellow and white body and a single blue eye moves towards the screen. It is surrounded by debris and fire.",
#     "objects_in_scene": ["robot", "debris", "fire"],
#     "dialog": "Oh oh",
#     "characters_in_scene": ["robot"]
#   },
#   {
#     "time_start": "00:06",
#     "time_end": "00:07",
#     "description": "The word 'NOW' appears in gold letters, superimposed on a background of red and yellow. ",
#     "objects_in_scene": [],
#     "dialog": "God, I hate this planet",
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:07",
#     "time_end": "00:08",
#     "description": "The woman with red hair walks down the stairs from a vehicle.",
#     "objects_in_scene": ["woman", "vehicle", "stairs"],
#     "dialog": "God, I hate this planet",
#     "characters_in_scene": ["woman"]
#   },
#   {
#     "time_start": "00:08",
#     "time_end": "00:09",
#     "description": "The title 'BORDERLANDS' appears in gold letters on a background of colorful splashes.",
#     "objects_in_scene": [],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:09",
#     "time_end": "00:10",
#     "description": "A man in a gas mask emerges from a hole in the ground. He is holding a large, metal disk.",
#     "objects_in_scene": ["man", "gas mask", "hole", "metal disk"],
#     "dialog": null,
#     "characters_in_scene": ["man"]
#   },
#   {
#     "time_start": "00:10",
#     "time_end": "00:13",
#     "description": "The man emerges from the hole, dropping the metal disk onto the ground. Three other people, including the woman with red hair and a woman with rabbit ears, are waiting for him.",
#     "objects_in_scene": ["man", "gas mask", "hole", "metal disk", "woman with red hair", "woman with rabbit ears", "ground"],
#     "dialog": null,
#     "characters_in_scene": ["man", "woman with red hair", "woman with rabbit ears"]
#   },
#   {
#     "time_start": "00:13",
#     "time_end": "00:16",
#     "description": "The four people are gathered around a small yellow robot. The robot is talking, and the others are looking at it.",
#     "objects_in_scene": ["four people", "yellow robot", "ground"],
#     "dialog": "What do you look at that? A ladder! Unfortunately, my design doesn't facilitate this type of",
#     "characters_in_scene": ["robot", "woman with red hair", "woman with rabbit ears", "man with gas mask"]
#   },
#   {
#     "time_start": "00:16",
#     "time_end": "00:17",
#     "description": "The robot moves forward on its single wheel. The woman with red hair is looking down at the robot.",
#     "objects_in_scene": ["robot", "woman with red hair", "ground"],
#     "dialog": null,
#     "characters_in_scene": ["robot", "woman with red hair"]
#   },
#   {
#     "time_start": "00:17",
#     "time_end": "00:18",
#     "description": "The group of four people runs across the desert landscape. A large, dark creature with tentacles flies above them.",
#     "objects_in_scene": ["four people", "desert landscape", "creature", "tentacles"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "man with gas mask", "man with hat"]
#   },
#   {
#     "time_start": "00:18",
#     "time_end": "00:22",
#     "description": "The group of four people are standing around a vehicle, looking down at the robot. The woman with red hair is talking.",
#     "objects_in_scene": ["four people", "vehicle", "robot", "desert landscape"],
#     "dialog": "Well, destiny awaits",
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "man with gas mask", "man with hat", "robot"]
#   },
#   {
#     "time_start": "00:22",
#     "time_end": "00:24",
#     "description": "Several logos appear on the screen, including 'LIONSGATE', 'A2 PRODUCTIONS', 'GEARBOX SOFTWARE', and '2K'. The setting is a dark, urban environment.",
#     "objects_in_scene": ["urban environment", "buildings"],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:24",
#     "time_end": "00:26",
#     "description": "A large building with a red sign that reads 'ATLAS CORPORATION' is seen in the distance. The woman with red hair stands in a dark environment, looking towards the camera.",
#     "objects_in_scene": ["building", "red sign", "woman with red hair"],
#     "dialog": "Legend has it that there's this massive treasure hidden in some secret vault.",
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "00:26",
#     "time_end": "00:31",
#     "description": "A spaceship orbits a planet. The camera pans to a dark chamber, revealing a glowing blue surface and gold blocks floating in the air. The woman with red hair walks through a doorway, holding a gun.",
#     "objects_in_scene": ["spaceship", "planet", "dark chamber", "glowing surface", "gold blocks", "woman with red hair", "gun"],
#     "dialog": "Legend has it that there's this massive treasure hidden in some secret vault.",
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "00:31",
#     "time_end": "00:33",
#     "description": "The woman with red hair walks through a dusty desert landscape, passing a sign with the word 'DAHL' on it.",
#     "objects_in_scene": ["woman with red hair", "desert landscape", "sign"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "00:33",
#     "time_end": "00:34",
#     "description": "A vehicle drives through a desert landscape. A man with a black beret stands in front of the vehicle, looking to the right. ",
#     "objects_in_scene": ["vehicle", "desert landscape", "man with beret"],
#     "dialog": "And if you go hunting for it, you'd better take any help you can get.",
#     "characters_in_scene": ["man with beret"]
#   },
#   {
#     "time_start": "00:34",
#     "time_end": "00:36",
#     "description": "A woman with rabbit ears looks through a telescope. The woman with red sunglasses stands in a room with a computer screen that displays a map.",
#     "objects_in_scene": ["woman with rabbit ears", "telescope", "woman with red sunglasses", "computer screen", "map"],
#     "dialog": "And if you go hunting for it, you'd better take any help you can get.",
#     "characters_in_scene": ["woman with rabbit ears", "woman with red sunglasses"]
#   },
#   {
#     "time_start": "00:36",
#     "time_end": "00:38",
#     "description": "A man with a gas mask and bare chest emerges from a vehicle, holding a large axe.",
#     "objects_in_scene": ["man with gas mask", "axe", "vehicle"],
#     "dialog": null,
#     "characters_in_scene": ["man with gas mask"]
#   },
#   {
#     "time_start": "00:38",
#     "time_end": "00:39",
#     "description": "The robot with the blue eye stands in a desert setting. The creature with tentacles flies over a mountain.",
#     "objects_in_scene": ["robot", "desert setting", "creature", "mountain"],
#     "dialog": null,
#     "characters_in_scene": ["robot"]
#   },
#   {
#     "time_start": "00:39",
#     "time_end": "00:42",
#     "description": "The creature with tentacles flies over a rocky terrain. The woman with red hair looks through binoculars. ",
#     "objects_in_scene": ["creature", "rocky terrain", "woman with red hair", "binoculars"],
#     "dialog": "Because it's got the weirdest, most dangerous dumpster fire of a world in the universe.",
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "00:42",
#     "time_end": "00:45",
#     "description": "A man wearing a mask and armor stands in front of several other masked figures. They all have weapons and are looking at the camera. Several vehicles drive through a desert setting.",
#     "objects_in_scene": ["man with mask", "armor", "masked figures", "weapons", "vehicles", "desert setting"],
#     "dialog": "Because it's got the weirdest, most dangerous dumpster fire of a world in the universe.",
#     "characters_in_scene": ["man with mask", "masked figures"]
#   },
#   {
#     "time_start": "00:45",
#     "time_end": "00:49",
#     "description": "A masked man stands in a dark setting, holding a torch. The camera pans to a group of people with masks, dancing in a circle around a fire.  The woman with red hair stands by a doorway in the vehicle.",
#     "objects_in_scene": ["masked man", "torch", "dark setting", "people with masks", "fire", "vehicle", "woman with red hair"],
#     "dialog": "God, I hate this planet.",
#     "characters_in_scene": ["woman with red hair", "masked man", "people with masks"]
#   },
#   {
#     "time_start": "00:49",
#     "time_end": "00:51",
#     "description": "The title 'BORDERLANDS' appears in gold letters on a background of colorful splashes.",
#     "objects_in_scene": [],
#     "dialog": "God, I hate this planet.",
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:51",
#     "time_end": "00:54",
#     "description": "The text 'FROM THE PRODUCER OF UNCHARTED SPIDER-MAN AND VENOM' appears in gold letters on a background of colorful splashes.",
#     "objects_in_scene": [],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "00:54",
#     "time_end": "00:56",
#     "description": "The woman with red hair sits in the front seat of a vehicle. The woman with rabbit ears sits next to her. The robot with the blue eye sits in the middle of the vehicle. The man with the beret drives.",
#     "objects_in_scene": ["woman with red hair", "woman with rabbit ears", "robot", "man with beret", "vehicle", "desert landscape"],
#     "dialog": "What is that smell? Tesquaish guly. Ew. Put the window up. I don't want to.",
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "robot", "man with beret"]
#   },
#   {
#     "time_start": "00:56",
#     "time_end": "01:01",
#     "description": "The vehicle drives through a desert landscape with a yellow mist. The woman with rabbit ears sits in the front seat and looks to the right.",
#     "objects_in_scene": ["vehicle", "desert landscape", "yellow mist", "woman with rabbit ears"],
#     "dialog": "Put the window up. I don't want to. Roll the window up.",
#     "characters_in_scene": ["woman with rabbit ears"]
#   },
#   {
#     "time_start": "01:01",
#     "time_end": "01:04",
#     "description": "The man with the beret continues to drive the vehicle through the desert landscape. The woman with red hair sits in the front seat, looking concerned. The robot sits in the middle of the vehicle.",
#     "objects_in_scene": ["man with beret", "vehicle", "woman with red hair", "robot", "desert landscape"],
#     "dialog": "It's piss. It's piss. Why do you think it's called pisswash? How did it get the name? It's in my mouth.",
#     "characters_in_scene": ["man with beret", "woman with red hair", "robot"]
#   },
#   {
#     "time_start": "01:04",
#     "time_end": "01:09",
#     "description": "The word 'THIS YEAR' appears in gold letters, superimposed on a background of red and yellow. The group of four people drives through a desert landscape in a vehicle.",
#     "objects_in_scene": ["vehicle", "desert landscape", "group of four people"],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "01:09",
#     "time_end": "01:12",
#     "description": "The vehicle drives through a desert landscape. The woman with red hair lies on a wooden platform.  A large, yellow vehicle crashes into several objects and explodes.",
#     "objects_in_scene": ["vehicle", "desert landscape", "woman with red hair", "wooden platform", "large yellow vehicle"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "01:12",
#     "time_end": "01:13",
#     "description": "The man with the gas mask walks through a dark corridor. ",
#     "objects_in_scene": ["man with gas mask", "dark corridor"],
#     "dialog": null,
#     "characters_in_scene": ["man with gas mask"]
#   },
#   {
#     "time_start": "01:13",
#     "time_end": "01:16",
#     "description": "The group of four people walks through a city. The woman with red hair wears a mask.  A large, yellow vehicle drives through a desert landscape, leaving a trail of dust in its wake.",
#     "objects_in_scene": ["group of four people", "woman with red hair", "mask", "city", "large yellow vehicle", "desert landscape"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "man with gas mask", "man with hat"]
#   },
#   {
#     "time_start": "01:16",
#     "time_end": "01:18",
#     "description": "The group of four people drives a vehicle through a desert landscape. The woman with red hair fires a gun. ",
#     "objects_in_scene": ["vehicle", "woman with red hair", "desert landscape", "gun"],
#     "dialog": "Do you know how many people have died looking for this vault?",
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "01:18",
#     "time_end": "01:22",
#     "description": "A large yellow vehicle drives through a desert landscape. The woman with red hair stands on the hood of a vehicle, firing a gun. ",
#     "objects_in_scene": ["large yellow vehicle", "woman with red hair", "vehicle", "desert landscape", "gun"],
#     "dialog": "Do you know how many people have died looking for this vault? We have something they don't, baby girl.",
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "01:22",
#     "time_end": "01:24",
#     "description": "The robot with the blue eye walks through a corridor.",
#     "objects_in_scene": ["robot", "corridor"],
#     "dialog": "We have something they don't, baby girl.",
#     "characters_in_scene": ["robot"]
#   },
#   {
#     "time_start": "01:24",
#     "time_end": "01:27",
#     "description": "The woman with red hair stands next to the large, yellow vehicle, aiming a gun towards the screen.",
#     "objects_in_scene": ["woman with red hair", "large yellow vehicle", "gun", "desert landscape"],
#     "dialog": "Okay, what? Major issues",
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "01:27",
#     "time_end": "01:28",
#     "description": "The man with the gas mask looks up towards the sky.  The word 'TO TAKE THIS PLANET ON' appears in gold letters, superimposed on a background of green and blue.",
#     "objects_in_scene": ["man with gas mask", "sky"],
#     "dialog": "Major issues",
#     "characters_in_scene": ["man with gas mask"]
#   },
#   {
#     "time_start": "01:28",
#     "time_end": "01:31",
#     "description": "A man with a beard stands in a desert landscape. The woman with red hair walks through a dark corridor.  A large, yellow vehicle drives through a desert landscape.",
#     "objects_in_scene": ["man with beard", "desert landscape", "woman with red hair", "dark corridor", "large yellow vehicle"],
#     "dialog": null,
#     "characters_in_scene": ["man with beard", "woman with red hair"]
#   },
#   {
#     "time_start": "01:31",
#     "time_end": "01:32",
#     "description": "The word 'YOU HAVE TO BE A LITTLE OFF' appears in gold letters, superimposed on a background of red and yellow.",
#     "objects_in_scene": [],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "01:32",
#     "time_end": "01:34",
#     "description": "A group of soldiers stand in a desert landscape, holding weapons. The woman with rabbit ears stands on top of a large yellow vehicle.",
#     "objects_in_scene": ["soldiers", "desert landscape", "weapons", "woman with rabbit ears", "large yellow vehicle"],
#     "dialog": null,
#     "characters_in_scene": ["soldiers", "woman with rabbit ears"]
#   },
#   {
#     "time_start": "01:34",
#     "time_end": "01:38",
#     "description": "The woman with rabbit ears stands on top of a large yellow vehicle. The large yellow vehicle is tilted at a steep angle, and the woman with rabbit ears looks over the edge.",
#     "objects_in_scene": ["woman with rabbit ears", "large yellow vehicle", "desert landscape"],
#     "dialog": "Time to make it rain with your body parts.",
#     "characters_in_scene": ["woman with rabbit ears"]
#   },
#   {
#     "time_start": "01:38",
#     "time_end": "01:40",
#     "description": "The woman with rabbit ears leaps off the vehicle and lands on the ground, with the large yellow vehicle falling on top of her. Several vehicles crash into the ground, exploding.",
#     "objects_in_scene": ["woman with rabbit ears", "large yellow vehicle", "desert landscape", "vehicles"],
#     "dialog": "Time to make it rain with your body parts.",
#     "characters_in_scene": ["woman with rabbit ears"]
#   },
#   {
#     "time_start": "01:40",
#     "time_end": "01:43",
#     "description": "The woman with red hair sits in the front seat of a vehicle. The woman with rabbit ears sits next to her. The man with the beret drives. The woman with red hair looks concerned.",
#     "objects_in_scene": ["woman with red hair", "woman with rabbit ears", "man with beret", "vehicle", "desert landscape"],
#     "dialog": "What did I tell you? Minimal explosions. I said no explosions.",
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "man with beret"]
#   },
#   {
#     "time_start": "01:43",
#     "time_end": "01:45",
#     "description": "The name 'CATE BLANCHETT' appears in gold letters, superimposed on a background of red and yellow.",
#     "objects_in_scene": [],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "01:45",
#     "time_end": "01:48",
#     "description": "The woman with red hair walks through a dark room. The name 'KEVIN HART' appears in gold letters, superimposed on a background of green and blue.",
#     "objects_in_scene": ["woman with red hair", "dark room"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "01:48",
#     "time_end": "01:52",
#     "description": "The man with the beret drives a vehicle through a desert landscape. The name 'JACK BLACK AS CLAPTRAP' appears in gold letters, superimposed on a background of red and yellow.",
#     "objects_in_scene": ["man with beret", "vehicle", "desert landscape"],
#     "dialog": null,
#     "characters_in_scene": ["man with beret"]
#   },
#   {
#     "time_start": "01:52",
#     "time_end": "01:56",
#     "description": "The robot with the blue eye runs towards the screen as a group of people chase after it. The name 'ARIANA GREENBLATT' appears in gold letters, superimposed on a background of green and blue.",
#     "objects_in_scene": ["robot", "group of people"],
#     "dialog": null,
#     "characters_in_scene": ["robot", "group of people"]
#   },
#   {
#     "time_start": "01:56",
#     "time_end": "01:59",
#     "description": "A woman in red armor drives through a desert landscape. The woman with rabbit ears stands on the edge of a vehicle and aims a large, black weapon.",
#     "objects_in_scene": ["woman in red armor", "desert landscape", "woman with rabbit ears", "vehicle", "large black weapon"],
#     "dialog": "Ooh. Mine's bigger.",
#     "characters_in_scene": ["woman with rabbit ears"]
#   },
#   {
#     "time_start": "01:59",
#     "time_end": "02:01",
#     "description": "The name 'AND JAMIE LEE CURTIS' appears in gold letters, superimposed on a background of red and yellow. The woman with red hair walks through a dark corridor, holding a gun. ",
#     "objects_in_scene": ["woman with red hair", "dark corridor", "gun"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair"]
#   },
#   {
#     "time_start": "02:01",
#     "time_end": "02:06",
#     "description": "The woman with red hair walks through a dark corridor. The man with the beret stands in the dark corridor, holding a gun.  The woman with red sunglasses walks through the dark corridor. The woman with rabbit ears stands in the middle of the corridor, looking around.",
#     "objects_in_scene": ["woman with red hair", "man with beret", "gun", "dark corridor", "woman with red sunglasses", "woman with rabbit ears"],
#     "dialog": "What in the... I needed a gun! So, you asked for it.",
#     "characters_in_scene": ["woman with red hair", "man with beret", "woman with red sunglasses", "woman with rabbit ears"]
#   },
#   {
#     "time_start": "02:06",
#     "time_end": "02:08",
#     "description": "The woman with red hair fires a gun, and fireworks go off in the background. The woman with rabbit ears looks to the left.",
#     "objects_in_scene": ["woman with red hair", "gun", "fireworks"],
#     "dialog": "There's only one way to be on the world, with your special",
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears"]
#   },
#   {
#     "time_start": "02:08",
#     "time_end": "02:11",
#     "description": "The robot with the blue eye walks through a dark corridor. The man with the beard stands in a desert landscape, pointing towards the screen.",
#     "objects_in_scene": ["robot", "dark corridor", "man with beard", "desert landscape"],
#     "dialog": "Oh oh. Kill them all.",
#     "characters_in_scene": ["robot", "man with beard"]
#   },
#   {
#     "time_start": "02:11",
#     "time_end": "02:13",
#     "description": "The group of people with masks fire weapons. The woman with red hair and the woman with rabbit ears run up the side of a vehicle. ",
#     "objects_in_scene": ["people with masks", "weapons", "woman with red hair", "woman with rabbit ears", "vehicle"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "people with masks"]
#   },
#   {
#     "time_start": "02:13",
#     "time_end": "02:15",
#     "description": "The robot with the blue eye walks through a dark corridor. The woman with red hair kneels on a rock in a desert landscape. The robot with the blue eye stands next to her.",
#     "objects_in_scene": ["robot", "dark corridor", "woman with red hair", "rock", "desert landscape"],
#     "dialog": null,
#     "characters_in_scene": ["robot", "woman with red hair"]
#   },
#   {
#     "time_start": "02:15",
#     "time_end": "02:18",
#     "description": "The group of people with masks walks through a dark corridor. The robot with the blue eye walks through a dark corridor, with objects flying at it.",
#     "objects_in_scene": ["group of people with masks", "dark corridor", "robot"],
#     "dialog": null,
#     "characters_in_scene": ["robot", "group of people with masks"]
#   },
#   {
#     "time_start": "02:18",
#     "time_end": "02:23",
#     "description": "The creature with tentacles stands in the middle of a desert landscape.  A vehicle drives towards the creature, and the creature roars. The woman with red hair sits in the front seat of the vehicle.  The woman with rabbit ears sits next to her. The man with the beret drives.",
#     "objects_in_scene": ["creature", "desert landscape", "vehicle", "woman with red hair", "woman with rabbit ears", "man with beret"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair", "woman with rabbit ears", "man with beret"]
#   },
#   {
#     "time_start": "02:23",
#     "time_end": "02:26",
#     "description": "The vehicle drives towards the creature. The woman with red hair screams as the creature roars. The vehicle crashes into the ground, and the creature attacks. The creature fires a beam of light from its mouth.  The robot with the blue eye sits in the middle of the vehicle.  The camera zooms in on the robot's eye. The creature roars again. ",
#     "objects_in_scene": ["creature", "vehicle", "woman with red hair", "robot", "desert landscape"],
#     "dialog": null,
#     "characters_in_scene": ["woman with red hair", "robot"]
#   },
#   {
#     "time_start": "02:26",
#     "time_end": "02:29",
#     "description": "The creature lunges forward, its mouth open and its teeth bared. The creature is engulfed in a cloud of dust.  A vehicle drives towards the creature, firing a weapon.  The creature roars and explodes. ",
#     "objects_in_scene": ["creature", "vehicle", "desert landscape"],
#     "dialog": null,
#     "characters_in_scene": []
#   },
#   {
#     "time_start": "02:29",
#     "time_end": "02:34",
#     "description": "The title 'BORDERLANDS' appears in gold letters on a background of colorful splashes. The robot with the blue eye walks through a dark corridor, with objects flying at it.",
#     "objects_in_scene": ["robot", "dark corridor"],
#     "dialog": null,
#     "characters_in_scene": ["robot"]
#   },
#   {
#     "time_start": "02:34",
#     "time_end": "02:37",
#     "description": "The robot with the blue eye walks through a dark corridor. The man with the beret stands in the dark corridor. The woman with red hair walks through the dark corridor.",
#     "objects_in_scene": ["robot", "dark corridor", "man with beret", "woman with red hair"],
#     "dialog": "What's happening right now? I'm expelling the excess lead.",
#     "characters_in_scene": ["robot", "man with beret", "woman with red hair"]
#   },
#   {
#     "time_start": "02:37",
#     "time_end": "02:41",
#     "description": "The robot with the blue eye walks through a dark corridor. The woman with rabbit ears stands in the dark corridor, looking at the robot.",
#     "objects_in_scene": ["robot", "dark corridor", "woman with rabbit ears"],
#     "dialog": "I'm expelling the excess lead. I can't go if you're looking at me.",
#     "characters_in_scene": ["robot", "woman with rabbit ears"]
#   },
#   {
#     "time_start": "02:41",
#     "time_end": "02:45",
#     "description": "The robot with the blue eye walks through a dark corridor. The woman with red hair walks through the dark corridor. The man with the gas mask walks behind her. The woman with red sunglasses walks behind the man with the gas mask.  The woman with rabbit ears stands in the dark corridor, looking at the robot.",
#     "objects_in_scene": ["robot", "dark corridor", "woman with red hair", "man with gas mask", "woman with red sunglasses", "woman with rabbit ears"],
#     "dialog": "Oops, actually, scrap that. I can, I really can. Actually, it's helping. Are we really going to first to finish?",
#     "characters_in_scene": ["robot", "woman with red hair", "man with gas mask", "woman with red sunglasses", "woman with rabbit ears"]
#   },
#   {
#     "time_start": "02:45",
#     "time_end": "02:52",
#     "description": "The group of four people walks through a dark corridor. The woman with rabbit ears looks at the robot.  The text 'COMING SOON' appears in gold letters, superimposed on a background of colorful splashes.

# %%
import cv2
from PIL import Image
import io
import vertexai
from vertexai.generative_models import GenerativeModel, Part
import google.generativeai as genai
from moviepy.editor import VideoFileClip


def describe_video_by_frames(video_path, frame_interval=5):
    try:
        vertexai.init(project='gen-lang-client-0004068608', location="us-west1")

        model = GenerativeModel(model_name="gemini-1.5-flash")
        # genai.configure(api_key=GEMINI_API_KEY)

        # model = genai.GenerativeModel(model_name="gemini-1.5-flash")
        
        # Prepare the prompt
        prompt = f'''
        Provide a description of the video based on the sequence of frames provided.
        The description should also contain anything important which people say in the video.
        Include key elements such as:
        1. Main subject or focus
        2. Setting or environment
        3. Actions or events occurring
        4. Notable visual elements or patterns
        5. Any text or recognizable logos
        6. Important dialogues or spoken content
        Summarize your observations in 3 sentences.

        Each frame is {frame_interval} seconds long.

        Output a list of JSON where each JSON object is the description per frame.
        Do not output any explanation. 
        Example JSON format:
        {
          "time_start": 00:00,
          "time_end": 00:05,
          "description": "frame_description",
          "objects_in_scene": ["object1", "object2", "object3", ...],
          "dialog": "transcript_of_dialog",
          "characters_in_scene": ["character1", "character2", ...]
        }
        Please provide your video description using this JSON format.
        mime_type=application/json
        Do not provide any explanation.
        Only output list of JSON
        
        '''

        # Extract frames from the video using MoviePy
        video = VideoFileClip(video_path)
        frames = []
        
        for t in range(0, int(video.duration), frame_interval):
            frame = video.get_frame(t)
            
            # Convert the frame to PIL Image
            pil_image = Image.fromarray(frame)
            
            # Save the image to a byte stream
            byte_arr = io.BytesIO()
            pil_image.save(byte_arr, format='JPEG')
            image_bytes = byte_arr.getvalue()
            
            # Create a Part object from the image bytes
            image_part = Part.from_data(data=image_bytes, mime_type="image/jpeg")
            frames.append(image_part)

        video.close()

        # Generate content using Gemini
        contents = frames + [prompt]
        response = model.generate_content(contents)
        return response.text
    except Exception as e:
        print(f"Error describing video: {e}")
        return f"Unable to generate video description. Error: {str(e)}"

# %%
video_description=describe_video_by_frames("/Users/dylan/Downloads/jasonwei-1.mp4")
# Out:
# Error describing video: Invalid format specifier ' 00:00,
#           "time_end": 00:05,
#           "description": "frame_description",
#           "objects_in_scene": ["object1", "object2", "object3", ...],
#           "dialog": "transcript_of_dialog",
#           "characters_in_scene": ["character1", "character2", ...]
#         ' for object of type 'str'

# %%
print(video_description)
# Out:
# Unable to generate video description. Error: Invalid format specifier ' 00:00,
#           "time_end": 00:05,
#           "description": "frame_description",
#           "objects_in_scene": ["object1", "object2", "object3", ...],
#           "dialog": "transcript_of_dialog",
#           "characters_in_scene": ["character1", "character2", ...]
#         ' for object of type 'str'

# %%
# model = GenerativeModel(model_name="gemini-1.5-flash")
genai.configure(api_key=GEMINI_API_KEY)

model = genai.GenerativeModel(model_name="gemini-1.5-flash")

model = GenerativeModel(model_name="gemini-1.5-flash")

# %%
image_file = Part.from_uri(
    "/Users/dylan/Downloads/00006737.jpg",
    mime_type="image/jpeg"
)

# Query the model
response = model.generate_content([image_file, "what is this image?"])
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/grpc/_channel.py:1176, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 (
#    1171     state,
#    1172     call,
#    1173 ) = self._blocking(
#    1174     request, timeout, metadata, credentials, wait_for_ready, compression
#    1175 )
# -> 1176 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/grpc/_channel.py:1005, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004 else:
# -> 1005     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.PERMISSION_DENIED
# 	details = "Permission 'aiplatform.endpoints.predict' denied on resource '//aiplatform.googleapis.com/projects/gen-lang-client-0004068608/locations/us-central1/publishers/google/models/gemini-1.5-flash' (or it may not exist)."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:142.251.214.138:443 {grpc_message:"Permission \'aiplatform.endpoints.predict\' denied on resource \'//aiplatform.googleapis.com/projects/gen-lang-client-0004068608/locations/us-central1/publishers/google/models/gemini-1.5-flash\' (or it may not exist).", grpc_status:7, created_time:"2024-06-24T11:34:14.440967-07:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# Cell In[92], line 7
#       1 image_file = Part.from_uri(
#       2     "/Users/dylan/Downloads/00006737.jpg",
#       3     mime_type="image/jpeg"
#       4 )
#       6 # Query the model
# ----> 7 response = model.generate_content([image_file, "what is this image?"])
#       8 print(response.text)
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:354, in _GenerativeModel.generate_content(self, contents, generation_config, safety_settings, tools, stream)
#     347     return self._generate_content_streaming(
#     348         contents=contents,
#     349         generation_config=generation_config,
#     350         safety_settings=safety_settings,
#     351         tools=tools,
#     352     )
#     353 else:
# --> 354     return self._generate_content(
#     355         contents=contents,
#     356         generation_config=generation_config,
#     357         safety_settings=safety_settings,
#     358         tools=tools,
#     359     )
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:435, in _GenerativeModel._generate_content(self, contents, generation_config, safety_settings, tools)
#     412 """Generates content.
#     413
#     414 Args:
#    (...)
#     427     A single GenerationResponse object
#     428 """
#     429 request = self._prepare_request(
#     430     contents=contents,
#     431     generation_config=generation_config,
#     432     safety_settings=safety_settings,
#     433     tools=tools,
#     434 )
# --> 435 gapic_response = self._prediction_client.generate_content(request=request)
#     436 return self._parse_response(gapic_response)
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/google/cloud/aiplatform_v1beta1/services/prediction_service/client.py:2075, in PredictionServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#    2072 self._validate_universe_domain()
#    2074 # Send the request.
# -> 2075 response = rpc(
#    2076     request,
#    2077     retry=retry,
#    2078     timeout=timeout,
#    2079     metadata=metadata,
#    2080 )
#    2082 # Done; return the response.
#    2083 return response
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/miniconda3/envs/python3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# PermissionDenied: 403 Permission 'aiplatform.endpoints.predict' denied on resource '//aiplatform.googleapis.com/projects/gen-lang-client-0004068608/locations/us-central1/publishers/google/models/gemini-1.5-flash' (or it may not exist). [reason: "IAM_PERMISSION_DENIED"
# domain: "aiplatform.googleapis.com"
# metadata {
#   key: "resource"
#   value: "projects/gen-lang-client-0004068608/locations/us-central1/publishers/google/models/gemini-1.5-flash"
# }
# metadata {
#   key: "permission"
#   value: "aiplatform.endpoints.predict"
# }
# ]
